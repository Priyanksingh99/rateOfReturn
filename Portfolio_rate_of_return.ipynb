# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

tickers = ['HDFC.NS','INFY.NS','TCS.NS']
my_data = pd.DataFrame()
for t in tickers:
    my_data[t] = wb.DataReader(t,data_source = 'yahoo',start = '2016-1-1')['Adj Close']

my_data
# Out:
#                 HDFC.NS      INFY.NS       TCS.NS
# Date
# 2016-01-01  1143.851562   467.716858  1068.502319
# 2016-01-04  1105.903809   456.566254  1047.808105
# 2016-01-05  1099.268311   454.513885  1038.676514
# 2016-01-06  1099.177246   452.524933  1053.113892
# 2016-01-07  1072.045898   444.675018  1048.537109
# ...                 ...          ...          ...
# 2022-07-04  2216.850098  1488.000000  3235.050049
# 2022-07-05  2202.899902  1475.949951  3216.300049
# 2022-07-06  2229.500000  1491.650024  3260.750000
# 2022-07-07  2245.550049  1498.699951  3287.850098
# 2022-07-08  2242.199951  1504.150024  3289.350098
#
# [1611 rows x 3 columns]

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1611 entries, 2016-01-01 to 2022-07-08
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   HDFC.NS  1611 non-null   float64
#  1   INFY.NS  1611 non-null   float64
#  2   TCS.NS   1611 non-null   float64
# dtypes: float64(3)
# memory usage: 50.3 KB

# %%
my_data.head()
# Out:
#                 HDFC.NS     INFY.NS       TCS.NS
# Date
# 2016-01-01  1143.851562  467.716858  1068.502319
# 2016-01-04  1105.903809  456.566254  1047.808105
# 2016-01-05  1099.268311  454.513885  1038.676514
# 2016-01-06  1099.177246  452.524933  1053.113892
# 2016-01-07  1072.045898  444.675018  1048.537109

# %%
my_data.tail()
# Out:
#                 HDFC.NS      INFY.NS       TCS.NS
# Date
# 2022-07-04  2216.850098  1488.000000  3235.050049
# 2022-07-05  2202.899902  1475.949951  3216.300049
# 2022-07-06  2229.500000  1491.650024  3260.750000
# 2022-07-07  2245.550049  1498.699951  3287.850098
# 2022-07-08  2242.199951  1504.150024  3289.350098

# %%
((my_data/my_data.iloc[0]) *100).plot(figsize = (15,6))
plt.show()

# %%
my_data.plot(figsize = (15,6))
plt.show()
